# %% [markdown]
# # Probability and Statistics Fall 1400
# ## Python Tutorial - Part 2_Seaborn
# * Prepared by : Shayan Vassef
# * Email : sh.vassef@ut.ac.ir
#
# ![Python](Python-Tutorial.png)

# %% [markdown]
# # Let's get started !

# %% [markdown]
# **This notebook will just go through the following topics in order:**
#
# * NumPy
#     * Built-in Methods
#     * Random
#     * Array Attributes and Methods
#     * Indexing and Selection
#     * Broadcasting
#     * Conditional Selection
#     * Operations
#     * Functions
# * pandas
#     * Series
#     * DataFrames
#     * Conditional filtering
#     * Practical methods
#     * Dealing with missing data
# * Matplotlib
#     * plt.plot() function calls
#     * Figure Object
#     * Sub Plots
#     * Styling
# * Seaborn
#     * Scatter-Plots
#     * Distribution-Plots
#     * Categorical-Plots-Statistical Estimation
#     * Categorical Plots - Distribution
#     * Comparison Plots
#     * Matrix Plots

# %% [markdown]
# # Seaborn

# %% [markdown]
# * Seaborn is a Statistical plotting library that is specifically designed to interact well with Pandas DataFrame to creat common   Statistical plot types.
# * Seaborn is built directly off of Matplotlib but uses a simpler "one-line" syntax.

# %% [markdown]
# # Common question :
# ## How do I choose which plot to use ?

# %% [markdown]
# ## Installation
#
# You'll need to install matplotlib first with either:
#
#     conda install seaborn
# or
#
#     pip install seaborn
#
# ## Importing

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("dm_office_sales.csv")
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %% [markdown]
# # <font color='green'>Scatterplot</font>

# %%
sns.scatterplot(x='salary',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ## Using Matplotlib to reorganized the current figure .

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ## Seaborn Parameters
#
# The hue and palette parameters are commonly available around many plot calls in seaborn.
#
# ### hue
#
# Color points based off a categorical feature in the DataFrame

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,hue='division')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,hue='work experience')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### palette
# **Choosing a palette from Matplotlib's cmap: https://matplotlib.org/tutorials/colors/colormaps.html**

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,hue='work experience',palette='viridis')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ## Scatterplot  Parameters
#
# These parameters are more specific to the scatterplot() call
#
# ### size
#
# Allows you to size based on another column

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,size='work experience')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,s=200)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=2,alpha=0.5)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### style
#
# Automatically choose styles based on another categorical feature in the dataset. Optionally use the **markers=** parameter to pass a list of marker choices based off matplotlib, for example: ['*','+','o']

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='salary',y='sales',data=df,style='level of education')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,8))
# Sometimes its nice to do BOTH hue and style off the same column
sns.scatterplot(x='salary',y='sales',data=df,style='level of education',hue='level of education',s=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# # <font color='green'>Distributions</font>
#
# There are many ways to display the distributions of a feature. In this notebook we explore 3 related plots for displaying a distribution,  the **rugplot , the distplot (histogram), and kdeplot.**

# %% [markdown]
# ## Rugplot
#
# Very simple plot that puts down one mark per data point. This plot needs the single array passed in directly. We won't use it too much since its not very clarifying for large data sets.

# %%
# The y axis doesn't really represent anything
# X axis is just a stick per data point
sns.rugplot(x='salary',data=df)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.rugplot(x='salary',data=df,height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# ## displot() and histplot()
# The rugplot itself is not very informative for larger data sets distribution around the mean since so many ticks makes it hard to distinguish one tick from another. Instead we should count the number of tick marks per some segment of the x axis, then construct a histogram from this.
#
# The displot is a plot type that can show you the distribution of a single feature. It is a histogram with the option of adding a "KDE" plot (Kernel Density Estimation) on top of the histogram. Let's explore its use cases and syntax.

# %% [markdown]
# ### displot()

# %%
sns.displot(data=df,x='salary',kde=True)

# %%
sns.displot(data=df,x='salary')

# %% [markdown]
# ### histplot()

# %%
sns.histplot(data=df,x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %% [markdown]
# ### Number of Bins

# %%
sns.histplot(data=df,x='salary',bins=10)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.histplot(data=df,x='salary',bins=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %% [markdown]
# ### Adding in a grid and styles
#
# You can reset to a different default style: one of {darkgrid, whitegrid, dark, white, ticks}.

# %%
sns.set(style='darkgrid')
sns.histplot(data=df,x='salary',bins=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.set(style='white')
sns.histplot(data=df,x='salary',bins=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %% [markdown]
# ### Adding in keywords from matplotlib
#
# Seaborn plots can accept keyword arguments directly from the matplotlib code that seaborn uses. Keep in mind, not every seaborn plot can accept all matplotlib arguments, but the main styling parameters are available.

# %%
sns.displot(data=df,x='salary',bins=20,kde=False,
            color='red',edgecolor='blue',lw=4,ls='--')

# %% [markdown]
# ## The Kernel Density Estimation Plot
#
# The KDE plot maps an estimate of a probability *density* function of a random variable. Kernel density estimation is a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample.

# %%
import numpy as np

# %%
np.random.seed(101)

sample_ages = np.random.randint(0,100,200)

# %%
sample_ages
# Out:
# array([95, 11, 81, 70, 63, 87, 75,  9, 77, 40,  4, 63, 40, 60, 92, 64,  5,
#        12, 93, 40, 49, 83,  8, 29, 59, 34, 44, 72, 19, 10, 76, 95, 87,  0,
#        73,  8, 62, 36, 83, 99, 28, 63,  7, 10, 52, 56, 38, 73, 52, 18, 71,
#        15, 44,  0, 12, 17, 75, 79, 97, 93, 24, 36, 63, 19, 35, 30, 10, 60,
#        20, 27,  8, 86, 26, 87, 46, 47, 54, 86,  9, 45,  2, 18, 58, 92, 11,
#        10, 94, 35, 28,  3, 83, 84, 47, 14, 69, 60, 69, 51,  6, 88, 71, 68,
#        23, 35, 79, 98, 67, 82, 57, 77, 46,  3, 46, 29, 86, 21, 21, 81, 23,
#        94, 71, 20, 27, 75,  5, 49, 86, 89, 63, 82, 77,  3, 56, 14, 49, 87,
#        52, 13, 47, 49, 24, 20, 64, 52, 60, 47, 29, 60, 53, 11, 40, 91, 45,
#        97, 24, 36, 38,  9, 52, 67, 43,  1, 79, 68, 68, 61, 18, 51, 14, 28,
#        17, 87, 46, 52, 16, 70, 71, 84, 10, 62, 96, 57, 23, 86, 85, 26, 76,
#        66, 54, 17, 65, 57, 89,  2, 80, 50, 66, 88, 79, 93])

# %%
sample_ages = pd.DataFrame(sample_ages,columns=["age"])
sample_ages.head()
# Out:
#    age
# 0   95
# 1   11
# 2   81
# 3   70
# 4   63

# %%
sns.rugplot(data=sample_ages,x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
plt.figure(figsize=(12,8))
sns.displot(data=sample_ages,x='age',bins=10,rug=True)

# %%
plt.figure(figsize=(12,8))
sns.displot(data=sample_ages,x='age',bins=10,rug=True,kde=True)

# %%
sns.kdeplot(data=sample_ages,x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ### Cut Off KDE
#
# We could cut off the KDE if we know our data has hard limits (no one can be a negative age and no one in the population can be older than 100 for some reason)

# %%
# plt.figure(figsize=(12,8))
sns.kdeplot(data=sample_ages,x='age',clip=[0,100])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ### Bandwidth
# By tunning the bandwith of the kernel,We make the KDE more "sensitive" to the data. Notice how with a smaller bandwith, the kernels don't stretch so wide, meaning we don't need the cut-off anymore. This is analagous to increasing the number of bins in a histogram (making the actual bins narrower).

# %%
sns.kdeplot(data=sample_ages,x='age',bw_adjust=0.1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages,x='age',bw_adjust=0.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=sample_ages,x='age',bw_adjust=1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# # <font color='green'>Categorical-Plots-Statistical Estimation</font>
# Often we have **categorical** data, meaning the data is in distinct groupings, such as Countries or Companies. There is no country value "between" USA and France and there is no company value "between" Google and Apple, unlike continuous data where we know values can exist between data points, such as age or price.

# %% [markdown]
# ## Countplot()
#
# A simple plot, it merely shows the total count of rows per category.

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='division',data=df)
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df)
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %% [markdown]
# ### Breakdown within another category with 'hue'

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df,hue='training level')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df,hue='training level',palette='Set1')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %% [markdown]
# # barplot()
#
# So far we've seen the y axis default to a count (similar to a .groupby(x_axis).count() call in pandas). We can expand our visualizations by specifying a specific continuous feature for the y-axis. Keep in mind, you should be careful with these plots, as they may imply a relationship continuity along the y axis where there is none.

# %%
plt.figure(figsize=(10,6),dpi=200)
# By default barplot() will show the mean
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,ci='sd',palette='Set1')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,ci='sd',hue='division',palette='Set1')
plt.legend(loc=(1,1))

# %% [markdown]
# # <font color='green'>Categorical Plots - Distribution</font>
# So far we've seen how to apply a statistical estimation (like mean or count) to categories and compare them to one another. Let's now explore how to visualize the distribution within categories. We already know about distplot() which allows to view the distribution of a single feature, now we will break down that same distribution per category.

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Boxplot
#
# A boxplot display distribution through the use of **quartiles** and an **IQR** for outliers.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,palette='Set1')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %% [markdown]
# ### Adding hue for further segmentation

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender',palette='Set1')

# Optional move the legend outside
plt.legend(bbox_to_anchor=(1.05, 1))

# %% [markdown]
# ### Boxplot Styling Parameters
#
# #### Orientation

# %%
# NOTICE HOW WE HAVE TO SWITCH X AND Y FOR THE ORIENTATION TO MAKE SENSE!
sns.boxplot(x='math score',y='parental level of education',data=df,orient='h',palette='Set1')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='parental level of education'>

# %% [markdown]
# #### Width

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender',width=0.3,palette='Set1')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %% [markdown]
# # <font color='green'>Comparison Plots</font>
# Comparison Plots are essentially **2-dimentional** versions of the plots we've learned about so far.

# %% [markdown]
# ## jointplot

# %%
sns.jointplot(x='math score',y='reading score',data=df)

# %% [markdown]
# ### Using hexagonz

# %%
sns.jointplot(x='math score',y='reading score',data=df,kind='hex')

# %% [markdown]
# ### Using kde

# %%
sns.jointplot(x='math score',y='reading score',data=df,kind='kde')

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='gender',palette='viridis')

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True)

# %%
sns.pairplot(df,hue='gender',palette='viridis',diag_kind='hist')

# %% [markdown]
# # <font color='green'>Matrix Plots</font>
# Matrix plots are the visual equivalent of displaying a pivot table.The Matrix plots displays all the data passed in , visualizing all the numeric values in a DataFrame.

# %% [markdown]
# ## The Data
#
# World Population Prospects publishes United Nations population estimates for all world countries and every year from 1950 to 2020, as well as projections for different scenarios (low, middle and high variants) from 2020 to 2100. The figures presented here correspond to middle variant projections for the given year.
#
# https://www.ined.fr/en/everything_about_population/data/all-countries/?lst_continent=900&lst_pays=926

# %%
df = pd.read_csv('country_table.csv')
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %% [markdown]
# ## Heatmap

# %%
df = df.set_index('Countries')
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11
# OCEANIA                                         16.939        12.79
# WORLD                                           27.492        10.36

# %%
# Clearly shows life expectancy in different units
sns.heatmap(df)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
rates = df.drop('Life expectancy',axis=1)
sns.heatmap(rates)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(rates,linewidth=0.5)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(rates,linewidth=0.5,annot=True)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
# Note how its not palette here
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %% [markdown]
# ## Clustermap
#
# Plot a matrix dataset as a hierarchically-clustered heatmap.

# %%
sns.clustermap(rates)

# %%
sns.clustermap(rates,col_cluster=False)

# %% [markdown]
# # <font color='blue'>That's enough for Seaborn ! See u in the next Tutorial </font>
